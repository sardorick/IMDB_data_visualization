# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv(r"C:\Users\Lenovo\OneDrive\Documents\Strive repos\IMDB_data_visualization\Finaldata.csv")
pd.set_option("max_colwidth", None)
df
# Out:
#                       Title  \
# 0                    Batman
# 1           West Side Story
# 2         Wyjazd na weekend
# 3            Mroczny Rycerz
# 4          Zaułek koszmarów
# ..                      ...
# 95                  Cruella
# 96  Nieoszlifowane diamenty
# 97          Milczenie owiec
# 98          Leon zawodowiec
# 99      Ojciec chrzestny II
#
#                                                                                                                                                                                                Descriptions  \
# 0         When the Riddler, a sadistic serial killer, begins murdering key political figures in Gotham, Batman is forced to investigate the city's hidden corruption and question his family's involvement.
# 1                     An adaptation of the 1957 musical, West Side Story explores forbidden love and the rivalry between the Jets and the Sharks, two teenage street gangs of different ethnic backgrounds.
# 2            A weekend getaway to Croatia that goes awry when a woman is accused of killing her best friend. As she attempts to clear her name and uncover the truth, her efforts unearth a painful secret.
# 3             When the menace known as the Joker wreaks havoc and chaos on the people of Gotham, Batman must accept one of the greatest psychological and physical tests of his ability to fight injustice.
# 4                                          An ambitious carny with a talent for manipulating people with a few well-chosen words hooks up with a female psychologist who is even more dangerous than he is.
# ..                                                                                                                                                                                                      ...
# 95                                                                                                                                     A live-action prequel feature film following a young Cruella de Vil.
# 96                                                      With his debts mounting and angry collectors closing in, a fast-talking New York City jeweler risks everything in hope of staying afloat and alive.
# 97                                      A young F.B.I. cadet must receive the help of an incarcerated and manipulative cannibal killer to help catch another serial killer, a madman who skins his victims.
# 98  12-year-old Mathilda is reluctantly taken in by Léon, a professional assassin, after her family is murdered. An unusual relationship forms as she becomes his protégée and learns the assassin's trade.
# 99                                     The early life and career of Vito Corleone in 1920s New York City is portrayed, while his son, Michael, expands and tightens his grip on the family crime syndicate.
#
#     Release                  directors  rating  durations    votes  \
# 0      2022                Matt Reeves     8.4      176.0  251,525
# 1      2021           Steven Spielberg     7.4      156.0   52,704
# 2      2022                Kim Farrant     5.6       89.0   13,644
# 3      2008          Christopher Nolan     9.1      152.0    2,522
# 4      2021         Guillermo del Toro     7.1      150.0   85,126
# ..      ...                        ...     ...        ...      ...
# 95     2021            Craig Gillespie     7.4      134.0  214,613
# 96     2019  Benny Safdie, Josh Safdie     7.4      135.0  261,581
# 97     1991             Jonathan Demme     8.6      118.0    1,374
# 98     1994                 Luc Besson     8.6      110.0    1,117
# 99     1974       Francis Ford Coppola     9.0      202.0    1,220
#
#                       genres  \
# 0       Action, Crime, Drama
# 1      Crime, Drama, Musical
# 2      Crime, Drama, Mystery
# 3       Action, Crime, Drama
# 4     Crime, Drama, Thriller
# ..                       ...
# 95  Adventure, Comedy, Crime
# 96    Crime, Drama, Thriller
# 97    Crime, Drama, Thriller
# 98      Action, Crime, Drama
# 99              Crime, Drama
#
#                                                               stars
# 0      Robert Pattinson, Zoë Kravitz, Jeffrey Wright, Colin Farrell
# 1         Ansel Elgort, Rachel Zegler, Ariana DeBose, David Alvarez
# 2        Leighton Meester, Christina Wolfe, Ziad Bakri, Luke Norris
# 3        Christian Bale, Heath Ledger, Aaron Eckhart, Michael Caine
# 4       Bradley Cooper, Cate Blanchett, Toni Collette, Willem Dafoe
# ..                                                              ...
# 95          Emma Stone, Emma Thompson, Joel Fry, Paul Walter Hauser
# 96            Adam Sandler, Julia Fox, Idina Menzel, Mesfin Lamengo
# 97  Jodie Foster, Anthony Hopkins, Lawrence A. Bonney, Kasi Lemmons
# 98            Jean Reno, Gary Oldman, Natalie Portman, Danny Aiello
# 99           Al Pacino, Robert De Niro, Robert Duvall, Diane Keaton
#
# [100 rows x 9 columns]

# %%
df_min_max_scaled = df.copy()

column = 'rating'
column1 = 'durations'


df_min_max_scaled[column, column1] = (df_min_max_scaled[column] - df_min_max_scaled[column].min()) / (df_min_max_scaled[column].max() - df_min_max_scaled[column].min()) / (df_min_max_scaled[column1] - df_min_max_scaled[column1].min()) / (df_min_max_scaled[column1].max() - df_min_max_scaled[column1].min())


# df_min_max_scaled[column1] = 

display(df_min_max_scaled)
# Out:
#                       Title  \
# 0                    Batman
# 1           West Side Story
# 2         Wyjazd na weekend
# 3            Mroczny Rycerz
# 4          Zaułek koszmarów
# ..                      ...
# 95                  Cruella
# 96  Nieoszlifowane diamenty
# 97          Milczenie owiec
# 98          Leon zawodowiec
# 99      Ojciec chrzestny II
#
#                                                                                                                                                                                                Descriptions  \
# 0         When the Riddler, a sadistic serial killer, begins murdering key political figures in Gotham, Batman is forced to investigate the city's hidden corruption and question his family's involvement.
# 1                     An adaptation of the 1957 musical, West Side Story explores forbidden love and the rivalry between the Jets and the Sharks, two teenage street gangs of different ethnic backgrounds.
# 2            A weekend getaway to Croatia that goes awry when a woman is accused of killing her best friend. As she attempts to clear her name and uncover the truth, her efforts unearth a painful secret.
# 3             When the menace known as the Joker wreaks havoc and chaos on the people of Gotham, Batman must accept one of the greatest psychological and physical tests of his ability to fight injustice.
# 4                                          An ambitious carny with a talent for manipulating people with a few well-chosen words hooks up with a female psychologist who is even more dangerous than he is.
# ..                                                                                                                                                                                                      ...
# 95                                                                                                                                     A live-action prequel feature film following a young Cruella de Vil.
# 96                                                      With his debts mounting and angry collectors closing in, a fast-talking New York City jeweler risks everything in hope of staying afloat and alive.
# 97                                      A young F.B.I. cadet must receive the help of an incarcerated and manipulative cannibal killer to help catch another serial killer, a madman who skins his victims.
# 98  12-year-old Mathilda is reluctantly taken in by Léon, a professional assassin, after her family is murdered. An unusual relationship forms as she becomes his protégée and learns the assassin's trade.
# 99                                     The early life and career of Vito Corleone in 1920s New York City is portrayed, while his son, Michael, expands and tightens his grip on the family crime syndicate.
#
#     Release                  directors  rating  durations    votes  \
# 0      2022                Matt Reeves     8.4      176.0  251,525
# 1      2021           Steven Spielberg     7.4      156.0   52,704
# 2      2022                Kim Farrant     5.6       89.0   13,644
# 3      2008          Christopher Nolan     9.1      152.0    2,522
# 4      2021         Guillermo del Toro     7.1      150.0   85,126
# ..      ...                        ...     ...        ...      ...
# 95     2021            Craig Gillespie     7.4      134.0  214,613
# 96     2019  Benny Safdie, Josh Safdie     7.4      135.0  261,581
# 97     1991             Jonathan Demme     8.6      118.0    1,374
# 98     1994                 Luc Besson     8.6      110.0    1,117
# 99     1974       Francis Ford Coppola     9.0      202.0    1,220
#
#                       genres  \
# 0       Action, Crime, Drama
# 1      Crime, Drama, Musical
# 2      Crime, Drama, Mystery
# 3       Action, Crime, Drama
# 4     Crime, Drama, Thriller
# ..                       ...
# 95  Adventure, Comedy, Crime
# 96    Crime, Drama, Thriller
# 97    Crime, Drama, Thriller
# 98      Action, Crime, Drama
# 99              Crime, Drama
#
#                                                               stars  \
# 0      Robert Pattinson, Zoë Kravitz, Jeffrey Wright, Colin Farrell
# 1         Ansel Elgort, Rachel Zegler, Ariana DeBose, David Alvarez
# 2        Leighton Meester, Christina Wolfe, Ziad Bakri, Luke Norris
# 3        Christian Bale, Heath Ledger, Aaron Eckhart, Michael Caine
# 4       Bradley Cooper, Cate Blanchett, Toni Collette, Willem Dafoe
# ..                                                              ...
# 95          Emma Stone, Emma Thompson, Joel Fry, Paul Walter Hauser
# 96            Adam Sandler, Julia Fox, Idina Menzel, Mesfin Lamengo
# 97  Jodie Foster, Anthony Hopkins, Lawrence A. Bonney, Kasi Lemmons
# 98            Jean Reno, Gary Oldman, Natalie Portman, Danny Aiello
# 99           Al Pacino, Robert De Niro, Robert Duvall, Diane Keaton
#
#     (rating, durations)
# 0              0.000074
# 1              0.000068
# 2              0.000255
# 3              0.000119
# 4              0.000066
# ..                  ...
# 95             0.000097
# 96             0.000095
# 97             0.000207
# 98             0.000269
# 99             0.000067
#
# [100 rows x 10 columns]

# %%
df['rating'].mean()
# Out:
# 7.431914893617024

# %%
df[['Release', 'rating']].groupby('Release').mean().plot(kind='bar', title='Average rating of movies per year', figsize=(10,10))
plt.xlabel('years')
plt.ylabel('rating')
plt.savefig('Average rating of movies per year.png')

# %%
df_min_max_scaled.plot.scatter(x='Release', y='rating', figsize=(10,10))
# df_min_max_scaled.plot(x='release', y='director')
plt.savefig('Average_scatterplt.png')

# %%
df['directors'].value_counts()
# Out:
# Christopher Nolan              6
# Martin Scorsese                4
# Francis Ford Coppola           4
# Benny Safdie, Josh Safdie      4
# Guy Ritchie                    4
# David Fincher                  4
# Kenneth Branagh                4
# Ethan Coen, Joel Coen          2
# Alan Taylor                    2
# Adil El Arbi, Bilall Fallah    2
# Edgar Wright                   2
# Pierre Perifel                 2
# Tom Gormican                   2
# Stephen Fingleton              2
# Brad Watson                    2
# Craig Gillespie                2
# Michael Bay                    2
# Matthew Vaughn                 2
# Graham Moore                   2
# Jonathan Demme                 2
# Antonio Campos                 2
# Régis Blondeau                 2
# Matt Reeves                    2
# Mary Harron                    2
# Jared Stern, Sam Levine        2
# Kim Farrant                    2
# Guillermo del Toro             2
# Ridley Scott                   2
# Jerome Robbins, Robert Wise    2
# Justin Lin                     2
# David Blue Garcia              2
# Todd Phillips                  2
# Tim Burton                     2
# Steven Spielberg               2
# Steven Soderbergh              2
# Sanjay Leela Bhansali          2
# Rian Johnson                   2
# Ilya Naishuller                2
# Frank Darabont                 2
# Denis Villeneuve               2
# Quentin Tarantino              2
# Luc Besson                     2
# Name: directors, dtype: int64

# %%
df['directors'].value_counts().nlargest(10).plot(kind='bar', title='Director with the highest number of films', figsize=(10,10))
plt.xlabel('Name of directors')
plt.ylabel('Number of movies')
plt.savefig('Director with the highest number of films.png')

# %%
df['stars'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>
