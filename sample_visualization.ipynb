# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv(r"C:\Users\Lenovo\OneDrive\Documents\Strive repos\IMDB_data_visualization\sample_dataset.csv")
pd.set_option("max_colwidth", None)
df
# Out:
#                           title  \
# 0            Mad Max: Fury Road
# 1                     Gone Girl
# 2                      Die Hard
# 3                    Black Swan
# 4    X-Men: Days of Future Past
# 5                         Logan
# 6                        Aliens
# 7  Kingsman: The Secret Service
# 8                          Argo
# 9                         Taken
#
#                                                                                                                                                                                                                    description  \
# 0                           In a post-apocalyptic wasteland, a woman rebels against a tyrannical ruler in search for her homeland with the aid of a group of female prisoners, a psychotic worshiper, and a drifter named Max.
# 1                                                    With his wife's disappearance having become the focus of an intense media circus, a man sees the spotlight turned on him when it's suspected that he may not be innocent.
# 2                                                                  An NYPD officer tries to save his wife and several others taken hostage by German terrorists during a Christmas party at the Nakatomi Plaza in Los Angeles.
# 3                                                                                                A committed dancer struggles to maintain her sanity after winning the lead role in a production of Tchaikovsky's "Swan Lake".
# 4                                                                          The X-Men send Wolverine to the past in a desperate effort to change history and prevent an event that results in doom for both humans and mutants.
# 5                         In a future where mutants are nearly extinct, an elderly and weary Logan leads a quiet life. But when Laura, a mutant child pursued by scientists, comes to him for help, he must get her to safety.
# 6          Fifty-seven years after surviving an apocalyptic attack aboard her space vessel by merciless space creatures, Officer Ripley awakens from hyper-sleep and tries to warn anyone who will listen about the predators.
# 7                                                                             A spy organisation recruits a promising street kid into the agency's training program, while a global threat emerges from a twisted tech genius.
# 8  Acting under the cover of a Hollywood producer scouting a location for a science fiction film, a CIA agent launches a dangerous operation to rescue six Americans in Tehran during the U.S. hostage crisis in Iran in 1979.
# 9                                                                      A retired CIA agent travels across Europe and relies on his old skills to save his estranged daughter, who has been kidnapped while on a trip to Paris.
#
#    release          director  rating  duration   votes  \
# 0     2015     George Miller     8.1       120  872463
# 1     2014     David Fincher     8.1       149  850088
# 2     1988    John McTiernan     8.2       132  779370
# 3     2010  Darren Aronofsky     8.0       108  694448
# 4     2014      Bryan Singer     7.9       132  656330
# 5     2017     James Mangold     8.1       137  640427
# 6     1986     James Cameron     8.3       137  648225
# 7     2014    Matthew Vaughn     7.7       129  586330
# 8     2012       Ben Affleck     7.7       120  568892
# 9     2008      Pierre Morel     7.8        90  562306
#
#                         genre  \
# 0   Action, Adventure, Sci-Fi
# 1    Drama, Mystery, Thriller
# 2            Action, Thriller
# 3             Drama, Thriller
# 4   Action, Adventure, Sci-Fi
# 5       Action, Drama, Sci-Fi
# 6   Action, Adventure, Sci-Fi
# 7   Action, Adventure, Comedy
# 8  Biography, Drama, Thriller
# 9            Action, Thriller
#
#                                                              stars  \
# 0          Tom Hardy, Charlize Theron, Nicholas Hoult, Zoë Kravitz
# 1     Ben Affleck, Rosamund Pike, Neil Patrick Harris, Tyler Perry
# 2  Bruce Willis, Alan Rickman, Bonnie Bedelia, Reginald VelJohnson
# 3        Natalie Portman, Mila Kunis, Vincent Cassel, Winona Ryder
# 4        Patrick Stewart, Ian McKellen, Hugh Jackman, James McAvoy
# 5         Hugh Jackman, Patrick Stewart, Dafne Keen, Boyd Holbrook
# 6        Sigourney Weaver, Michael Biehn, Carrie Henn, Paul Reiser
# 7     Colin Firth, Taron Egerton, Samuel L. Jackson, Michael Caine
# 8            Ben Affleck, Bryan Cranston, John Goodman, Alan Arkin
# 9           Liam Neeson, Maggie Grace, Famke Janssen, Leland Orser
#
#    budget ($ Mil)  Rating / Votes
# 0          154.06        0.092841
# 1          167.77        0.095284
# 2           83.01        0.105213
# 3          106.95        0.115199
# 4          233.92        0.120366
# 5          226.28        0.126478
# 6           85.16        0.128042
# 7          128.26        0.131325
# 8          136.03        0.135351
# 9          145.00        0.138715

# %%
df_min_max_scaled = df.copy()

column = 'rating'
column1 = 'duration'


df_min_max_scaled[column, column1] = (df_min_max_scaled[column] - df_min_max_scaled[column].min()) / (df_min_max_scaled[column].max() - df_min_max_scaled[column].min()) / (df_min_max_scaled[column1] - df_min_max_scaled[column1].min()) / (df_min_max_scaled[column1].max() - df_min_max_scaled[column1].min())


# df_min_max_scaled[column1] = 

display(df_min_max_scaled)
# Out:
#                           title  \
# 0            Mad Max: Fury Road
# 1                     Gone Girl
# 2                      Die Hard
# 3                    Black Swan
# 4    X-Men: Days of Future Past
# 5                         Logan
# 6                        Aliens
# 7  Kingsman: The Secret Service
# 8                          Argo
# 9                         Taken
#
#                                                                                                                                                                                                                    description  \
# 0                           In a post-apocalyptic wasteland, a woman rebels against a tyrannical ruler in search for her homeland with the aid of a group of female prisoners, a psychotic worshiper, and a drifter named Max.
# 1                                                    With his wife's disappearance having become the focus of an intense media circus, a man sees the spotlight turned on him when it's suspected that he may not be innocent.
# 2                                                                  An NYPD officer tries to save his wife and several others taken hostage by German terrorists during a Christmas party at the Nakatomi Plaza in Los Angeles.
# 3                                                                                                A committed dancer struggles to maintain her sanity after winning the lead role in a production of Tchaikovsky's "Swan Lake".
# 4                                                                          The X-Men send Wolverine to the past in a desperate effort to change history and prevent an event that results in doom for both humans and mutants.
# 5                         In a future where mutants are nearly extinct, an elderly and weary Logan leads a quiet life. But when Laura, a mutant child pursued by scientists, comes to him for help, he must get her to safety.
# 6          Fifty-seven years after surviving an apocalyptic attack aboard her space vessel by merciless space creatures, Officer Ripley awakens from hyper-sleep and tries to warn anyone who will listen about the predators.
# 7                                                                             A spy organisation recruits a promising street kid into the agency's training program, while a global threat emerges from a twisted tech genius.
# 8  Acting under the cover of a Hollywood producer scouting a location for a science fiction film, a CIA agent launches a dangerous operation to rescue six Americans in Tehran during the U.S. hostage crisis in Iran in 1979.
# 9                                                                      A retired CIA agent travels across Europe and relies on his old skills to save his estranged daughter, who has been kidnapped while on a trip to Paris.
#
#    release          director  rating  duration   votes  \
# 0     2015     George Miller     8.1       120  872463
# 1     2014     David Fincher     8.1       149  850088
# 2     1988    John McTiernan     8.2       132  779370
# 3     2010  Darren Aronofsky     8.0       108  694448
# 4     2014      Bryan Singer     7.9       132  656330
# 5     2017     James Mangold     8.1       137  640427
# 6     1986     James Cameron     8.3       137  648225
# 7     2014    Matthew Vaughn     7.7       129  586330
# 8     2012       Ben Affleck     7.7       120  568892
# 9     2008      Pierre Morel     7.8        90  562306
#
#                         genre  \
# 0   Action, Adventure, Sci-Fi
# 1    Drama, Mystery, Thriller
# 2            Action, Thriller
# 3             Drama, Thriller
# 4   Action, Adventure, Sci-Fi
# 5       Action, Drama, Sci-Fi
# 6   Action, Adventure, Sci-Fi
# 7   Action, Adventure, Comedy
# 8  Biography, Drama, Thriller
# 9            Action, Thriller
#
#                                                              stars  \
# 0          Tom Hardy, Charlize Theron, Nicholas Hoult, Zoë Kravitz
# 1     Ben Affleck, Rosamund Pike, Neil Patrick Harris, Tyler Perry
# 2  Bruce Willis, Alan Rickman, Bonnie Bedelia, Reginald VelJohnson
# 3        Natalie Portman, Mila Kunis, Vincent Cassel, Winona Ryder
# 4        Patrick Stewart, Ian McKellen, Hugh Jackman, James McAvoy
# 5         Hugh Jackman, Patrick Stewart, Dafne Keen, Boyd Holbrook
# 6        Sigourney Weaver, Michael Biehn, Carrie Henn, Paul Reiser
# 7     Colin Firth, Taron Egerton, Samuel L. Jackson, Michael Caine
# 8            Ben Affleck, Bryan Cranston, John Goodman, Alan Arkin
# 9           Liam Neeson, Maggie Grace, Famke Janssen, Leland Orser
#
#    budget ($ Mil)  Rating / Votes  (rating, duration)
# 0          154.06        0.092841            0.000377
# 1          167.77        0.095284            0.000192
# 2           83.01        0.105213            0.000336
# 3          106.95        0.115199            0.000471
# 4          233.92        0.120366            0.000135
# 5          226.28        0.126478            0.000240
# 6           85.16        0.128042            0.000361
# 7          128.26        0.131325            0.000000
# 8          136.03        0.135351            0.000000
# 9          145.00        0.138715                 inf

# %%
df['rating'].mean()
# Out:
# 7.99

# %%
df[['release', 'rating']].groupby('release').mean().plot(kind='bar', title='Average rating of movies per year', figsize=(10,10))
plt.xlabel('years')
plt.ylabel('rating')
# Out:
# Text(0, 0.5, 'rating')

# %%
df_min_max_scaled.plot.scatter(x='rating', y='release', figsize=(10,10))
# df_min_max_scaled.plot(x='release', y='director')
# Out:
# <AxesSubplot:xlabel='rating', ylabel='release'>

# %%
df['director'].value_counts()
# Out:
# George Miller       1
# David Fincher       1
# John McTiernan      1
# Darren Aronofsky    1
# Bryan Singer        1
# James Mangold       1
# James Cameron       1
# Matthew Vaughn      1
# Ben Affleck         1
# Pierre Morel        1
# Name: director, dtype: int64

# %%
df['director'].value_counts().nlargest(10).plot(kind='bar', title='Number of Movies by each director', figsize=(10,10))
plt.xlabel('Name of directors')
plt.ylabel('Number of movies')
# Out:
# Text(0, 0.5, 'Number of movies')

# %%
df['stars'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>
